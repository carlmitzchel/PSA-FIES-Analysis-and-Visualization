# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler


#show all columns on output
pd.set_option('display.max_columns', None)

# %%
# Data Exploration
df = pd.read_excel('data/online_retail_II.xlsx', sheet_name=0)
df.head(10)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5  489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6  489434     21871                  SAVE THE PLANET MUG        24
# 7  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8  489435     22350                            CAT BOWL         12
# 9  489435     22349       DOG BOWL , CHASING BALL DESIGN        12
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
df.describe(include='O')
# Out:
#         Invoice StockCode                         Description         Country
# count    525461    525461                              522533          525461
# unique    28816      4632                                4681              40
# top      537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq        675      3516                                3549          485852

# %%
df[df["Customer ID"].isna()].head(10)
# Out:
#      Invoice StockCode                   Description  Quantity  \
# 263   489464     21733                  85123a mixed       -96
# 283   489463     71477                         short      -240
# 284   489467    85123A                   21733 mixed      -192
# 470   489521     21646                           NaN       -50
# 577   489525    85226C     BLUE PULL BACK RACING CAR         1
# 578   489525     85227   SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271          FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254          FELT TOADSTOOL LARGE        12
# 1057  489548     22273          FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195  LARGE HEART MEASURING SPOONS         1
#
#              InvoiceDate  Price  Customer ID         Country
# 263  2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 283  2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 284  2009-12-01 10:53:00   0.00          NaN  United Kingdom
# ...

# %%
df[df['Quantity'] < 0].head(10)
# Out:
#      Invoice StockCode                        Description  Quantity  \
# 178  C489449     22087           PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A       CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895      POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896                 POTTING SHED TWINE        -6
# 182  C489449     22083         PAPER CHAIN KIT RETRO SPOT       -12
# 183  C489449     21871                SAVE THE PLANET MUG       -12
# 184  C489449     84946    ANTIQUE SILVER TEA GLASS ETCHED       -12
# 185  C489449    84970S  HANGING HEART ZINC T-LIGHT HOLDER       -24
# 186  C489449     22090          PAPER BUNTING RETRO SPOTS       -12
# 196  C489459    90200A         PURPLE SWEETHEART BRACELET        -3
#
#             InvoiceDate  Price  Customer ID         Country
# 178 2009-12-01 10:33:00   2.95      16321.0       Australia
# 179 2009-12-01 10:33:00   1.65      16321.0       Australia
# ...

# %%
df['Invoice'] = df['Invoice'].astype('str')
df[df['Invoice'].str.match("^\\d{6}$") == False]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %%
df['Invoice'].str.replace("[0-9]", "", regex=True).unique()
# Out:
# array(['', 'C', 'A'], dtype=object)

# %%
df[df['Invoice'].str.startswith("A")]
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom

# %%
df['StockCode'] = df['StockCode'].astype('str')
df[(df["StockCode"].str.match("^\d{5}$") == False) & (df["StockCode"].str.match("^\d{5}[a-zA-Z]+$") == False)]["StockCode"].unique()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\edjin\AppData\Local\Temp\ipykernel_22688\4254394896.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df[(df["StockCode"].str.match("^\d{5}$") == False) & (df["StockCode"].str.match("^\d{5}[a-zA-Z]+$") == False)]["StockCode"].unique()
# C:\Users\edjin\AppData\Local\Temp\ipykernel_22688\4254394896.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df[(df["StockCode"].str.match("^\d{5}$") == False) & (df["StockCode"].str.match("^\d{5}[a-zA-Z]+$") == False)]["StockCode"].unique()
# array(['POST', 'D', 'DCGS0058', 'DCGS0068', 'DOT', 'M', 'DCGS0004',
#        'DCGS0076', 'C2', 'BANK CHARGES', 'DCGS0003', 'TEST001',
#        'gift_0001_80', 'DCGS0072', 'gift_0001_20', 'DCGS0044', 'TEST002',
#        'gift_0001_10', 'gift_0001_50', 'DCGS0066N', 'gift_0001_30',
# ...

# %%
df[df["StockCode"].str.contains("^BANK CHARGES")]
# Out:
#         Invoice     StockCode    Description  Quantity         InvoiceDate  \
# 18410   C490943  BANK CHARGES   Bank Charges        -1 2009-12-08 14:08:00
# 18466    490948  BANK CHARGES   Bank Charges         1 2009-12-08 14:29:00
# 33435   C492206  BANK CHARGES   Bank Charges        -1 2009-12-15 16:32:00
# 55948   C494438  BANK CHARGES   Bank Charges        -1 2010-01-14 12:15:00
# 94431    498269  BANK CHARGES   Bank Charges         1 2010-02-17 15:03:00
# ...         ...           ...            ...       ...                 ...
# 450634  C532203  BANK CHARGES   Bank Charges        -1 2010-11-11 12:31:00
# 455268   532637  BANK CHARGES   Bank Charges         1 2010-11-12 16:18:00
# 493162   535474  BANK CHARGES   Bank Charges         1 2010-11-26 13:56:00
# 507344   536779  BANK CHARGES   Bank Charges         1 2010-12-02 15:08:00
# 517373  C537572  BANK CHARGES   Bank Charges        -1 2010-12-07 12:00:00
#
#          Price  Customer ID         Country
# ...

# %% [markdown]
# ### Data Cleaning

# %%
cleaned_df = df.copy()

# %%
cleaned_df["Invoice"] = cleaned_df["Invoice"].astype('str')
mask = cleaned_df["Invoice"].str.match("^\\d{6}$") == True

cleaned_df = cleaned_df[mask]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 515252 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      515252 non-null  object
#  1   StockCode    515252 non-null  object
#  2   Description  512324 non-null  object
#  3   Quantity     515252 non-null  int64
#  4   InvoiceDate  515252 non-null  datetime64[ns]
#  5   Price        515252 non-null  float64
#  6   Customer ID  407695 non-null  float64
#  7   Country      515252 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 35.4+ MB

# %%
cleaned_df["StockCode"] = cleaned_df["StockCode"].astype('str')
mask = (
    (cleaned_df["StockCode"].str.match("^\\d{5}$") == True) 
    | (cleaned_df["StockCode"].str.match("^\\d{5}[a-zA-Z]+$") == True)
    | (cleaned_df["StockCode"].str.contains("^PADS") == True)
)

cleaned_df = cleaned_df[mask]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 512796 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      512796 non-null  object
#  1   StockCode    512796 non-null  object
#  2   Description  509916 non-null  object
#  3   Quantity     512796 non-null  int64
#  4   InvoiceDate  512796 non-null  datetime64[ns]
#  5   Price        512796 non-null  float64
#  6   Customer ID  406337 non-null  float64
#  7   Country      512796 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 35.2+ MB

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  512796.000000                         512796  512796.000000
# mean       11.001279  2010-06-28 18:26:52.709732352       3.391447
# min     -9600.000000            2009-12-01 07:45:00       0.000000
# 25%         1.000000            2010-03-21 13:27:00       1.250000
# 50%         3.000000            2010-07-06 14:25:00       2.100000
# 75%        10.000000            2010-10-15 14:50:00       4.210000
# max     19152.000000            2010-12-09 20:01:00    1157.150000
# std       104.352433                            NaN       5.067864
#
#          Customer ID
# count  406337.000000
# mean    15373.632992
# min     12346.000000
# 25%     14004.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.365907

# %%
cleaned_df[cleaned_df['Price'] == 0]
# Out:
#        Invoice StockCode   Description  Quantity         InvoiceDate  Price  \
# 263     489464     21733  85123a mixed       -96 2009-12-01 10:52:00    0.0
# 283     489463     71477         short      -240 2009-12-01 10:52:00    0.0
# 284     489467    85123A   21733 mixed      -192 2009-12-01 10:53:00    0.0
# 470     489521     21646           NaN       -50 2009-12-01 11:44:00    0.0
# 3114    489655     20683           NaN       -44 2009-12-01 17:26:00    0.0
# ...        ...       ...           ...       ...                 ...    ...
# 525231  538159     21324           NaN       -18 2010-12-09 17:17:00    0.0
# 525232  538158     20892           NaN       -32 2010-12-09 17:17:00    0.0
# 525233  538160     20956           NaN       288 2010-12-09 17:18:00    0.0
# 525234  538161    46000S  Dotcom sales      -100 2010-12-09 17:25:00    0.0
# 525235  538162    46000M  Dotcom sales      -100 2010-12-09 17:25:00    0.0
#
#         Customer ID         Country
# ...

# %%
cleaned_df = cleaned_df[cleaned_df['Price'] > 0.0]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 509165 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      509165 non-null  object
#  1   StockCode    509165 non-null  object
#  2   Description  509165 non-null  object
#  3   Quantity     509165 non-null  int64
#  4   InvoiceDate  509165 non-null  datetime64[ns]
#  5   Price        509165 non-null  float64
#  6   Customer ID  406309 non-null  float64
#  7   Country      509165 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 35.0+ MB

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  509165.000000                         509165  509165.000000
# mean       11.441085  2010-06-28 22:57:02.563845120       3.415633
# min         1.000000            2009-12-01 07:45:00       0.001000
# 25%         1.000000            2010-03-21 15:16:00       1.250000
# 50%         3.000000            2010-07-07 09:49:00       2.100000
# 75%        11.000000            2010-10-15 15:38:00       4.210000
# max     19152.000000            2010-12-09 20:01:00    1157.150000
# std        86.961888                            NaN       5.077775
#
#          Customer ID
# count  406309.000000
# mean    15373.722268
# min     12346.000000
# 25%     14006.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.329470

# %%
len(cleaned_df[cleaned_df['Price'] < 0.1])
# Out:
# 116

# %%
cleaned_df['Price'].min()
# Out:
# 0.001

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  509165.000000                         509165  509165.000000
# mean       11.441085  2010-06-28 22:57:02.563845120       3.415633
# min         1.000000            2009-12-01 07:45:00       0.001000
# 25%         1.000000            2010-03-21 15:16:00       1.250000
# 50%         3.000000            2010-07-07 09:49:00       2.100000
# 75%        11.000000            2010-10-15 15:38:00       4.210000
# max     19152.000000            2010-12-09 20:01:00    1157.150000
# std        86.961888                            NaN       5.077775
#
#          Customer ID
# count  406309.000000
# mean    15373.722268
# min     12346.000000
# 25%     14006.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.329470

# %%
cleaned_df.dropna(subset=['Customer ID'], inplace=True)

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  406309.000000                         406309  406309.000000
# mean       13.617924  2010-07-01 10:14:25.869572352       2.991668
# min         1.000000            2009-12-01 07:45:00       0.001000
# 25%         2.000000            2010-03-26 14:01:00       1.250000
# 50%         5.000000            2010-07-09 15:48:00       1.950000
# 75%        12.000000            2010-10-14 17:09:00       3.750000
# max     19152.000000            2010-12-09 20:01:00     295.000000
# std        96.998833                            NaN       4.285951
#
#          Customer ID
# count  406309.000000
# mean    15373.722268
# min     12346.000000
# 25%     14006.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.329470

# %%
len(cleaned_df)/len(df)
# Out:
# 0.7732429238325965

# %% [markdown]
# ### Feature Engineering

# %%
cleaned_df["SalesLineTotal"] = cleaned_df["Quantity"] * cleaned_df["Price"]

# %%
cleaned_df.head(10)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5  489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6  489434     21871                  SAVE THE PLANET MUG        24
# 7  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8  489435     22350                            CAT BOWL         12
# 9  489435     22349       DOG BOWL , CHASING BALL DESIGN        12
#
#           InvoiceDate  Price  Customer ID         Country  SalesLineTotal
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom            83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom            81.0
# ...

# %%
aggregated_df = cleaned_df.groupby("Customer ID", as_index=False) \
    .agg(
        MonetaryValue=('SalesLineTotal', 'sum'),
        Frequency=('Invoice', 'nunique'),
        LastInvoiceDate = ('InvoiceDate', 'max')
    )

# %%
aggregated_df.head(10)
# Out:
#    Customer ID  MonetaryValue  Frequency     LastInvoiceDate
# 0      12346.0         169.36          2 2010-06-28 13:53:00
# 1      12347.0        1323.32          2 2010-12-07 14:57:00
# 2      12348.0         221.16          1 2010-09-27 14:59:00
# 3      12349.0        2221.14          2 2010-10-28 08:23:00
# 4      12351.0         300.93          1 2010-11-29 15:23:00
# 5      12352.0         343.80          2 2010-11-29 10:07:00
# 6      12353.0         317.76          1 2010-10-27 12:44:00
# 7      12355.0         488.21          1 2010-05-21 11:59:00
# 8      12356.0        3126.25          3 2010-11-24 12:24:00
# 9      12357.0       11229.99          1 2010-11-16 10:05:00

# %%
max_invoice_date = aggregated_df["LastInvoiceDate"].max()

aggregated_df["Recency"] = (max_invoice_date - aggregated_df["LastInvoiceDate"]).dt.days

# %%
aggregated_df.head(10)
# Out:
#    Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency
# 0      12346.0         169.36          2 2010-06-28 13:53:00      164
# 1      12347.0        1323.32          2 2010-12-07 14:57:00        2
# 2      12348.0         221.16          1 2010-09-27 14:59:00       73
# 3      12349.0        2221.14          2 2010-10-28 08:23:00       42
# 4      12351.0         300.93          1 2010-11-29 15:23:00       10
# 5      12352.0         343.80          2 2010-11-29 10:07:00       10
# 6      12353.0         317.76          1 2010-10-27 12:44:00       43
# 7      12355.0         488.21          1 2010-05-21 11:59:00      202
# 8      12356.0        3126.25          3 2010-11-24 12:24:00       15
# 9      12357.0       11229.99          1 2010-11-16 10:05:00       23

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(data=aggregated_df['MonetaryValue'], color='skyblue')
plt.title('Monetary Value Boxplot')
plt.xlabel('Monetary Value')

plt.subplot(1, 3, 2)
sns.boxplot(data=aggregated_df['Frequency'], color='lightgreen')
plt.title('Frequency Boxplot')
plt.xlabel('Frequency')

plt.subplot(1, 3, 3)
sns.boxplot(data=aggregated_df['Recency'], color='salmon')
plt.title('Recency Boxplot')
plt.xlabel('Recency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(data=aggregated_df['MonetaryValue'], color='skyblue')
plt.title('Monetary Value Boxplot')
plt.xlabel('Monetary Value')

plt.subplot(1, 3, 2)
sns.boxplot(data=aggregated_df['Frequency'], color='lightgreen')
plt.title('Frequency Boxplot')
plt.xlabel('Frequency')

plt.subplot(1, 3, 3)
sns.boxplot(data=aggregated_df['Recency'], color='salmon')
plt.title('Recency Boxplot')
plt.xlabel('Recency')

plt.tight_layout()
plt.show()

# %%
M_Q1 = aggregated_df['MonetaryValue'].quantile(0.75)
M_Q3 = aggregated_df['MonetaryValue'].quantile(0.25)

M_IQR = M_Q3 - M_Q1

monetary_outliers = aggregated_df[(aggregated_df['MonetaryValue'] > (M_Q3 + 1.5 * M_IQR)) | (aggregated_df['MonetaryValue'] > (M_Q3 + 1.5 * M_IQR))]
